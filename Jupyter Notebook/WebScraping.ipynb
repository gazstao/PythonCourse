# %%
requisicao = requests.get("http://www.ongsbrasil.com.br/default.asp?Pag=1&amp;Destino=Instituicoes&amp;Estado=PI

# %%
import requests
from bs4 import BeautifulSoup

# %%
requisicao = requests.get("http://www.ongsbrasil.com.br/default.asp?Pag=1&Destino=Instituicoes", headers={'User-agent': 'Mozilla/5.0 (X11; Ubuntu; Linux x86_64; rv:61.0) Gecko/20100101 Firefox/61.0'})
conteudo = requisicao.content
conteudo = BeautifulSoup(conteudo,"html.parser")
print (conteudo)
# Out:
# <html>
# <head>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="width=device-width, initial-scale=1, maximum-scale=1" name="viewport"/>
# <meta content="ong, organização social, instituto, projeto social" name="KEYWORDS"/>
# <meta content="Veja aqui a lista de ONGs e organizações sociais do Brasil. Compartilhe informações sobre as instituições. Veja comentários, fotos e vídeos. Descubra como doar ou fazer trabalho voluntário." name="Description"/>
# <title>Lista de ONGs brasileiras - para Trabalho Voluntário e Doações - ONGs Brasil</title>
# <link href="http://www.ongsbrasil.com.br/images/favicon.png" rel="icon" type="image/png"/>
# <link href="bootstrap/css/bootstrap.min.css" rel="stylesheet"/>
# <link href="estiloOngs.css" rel="stylesheet" type="text/css"/>
# <link href="http://www.ongsbrasil.com.br/default.asp?Pag=1&amp;Destino=Instituicoes" rel="canonical">
# <script>
# ...

# %%
import requests
from bs4 import BeautifulSoup

requisicao = requests.get("http://www.ongsbrasil.com.br/default.asp?Pag=1&Destino=Instituicoes", headers={'User-agent': 'Mozilla/5.0 (X11; Ubuntu; Linux x86_64; rv:61.0) Gecko/20100101 Firefox/61.0'})
conteudo = requisicao.content
conteudo = BeautifulSoup(conteudo,"html.parser")
print (conteudo)
# Out:
# <html>
# <head>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="width=device-width, initial-scale=1, maximum-scale=1" name="viewport"/>
# <meta content="ong, organização social, instituto, projeto social" name="KEYWORDS"/>
# <meta content="Veja aqui a lista de ONGs e organizações sociais do Brasil. Compartilhe informações sobre as instituições. Veja comentários, fotos e vídeos. Descubra como doar ou fazer trabalho voluntário." name="Description"/>
# <title>Lista de ONGs brasileiras - para Trabalho Voluntário e Doações - ONGs Brasil</title>
# <link href="http://www.ongsbrasil.com.br/images/favicon.png" rel="icon" type="image/png"/>
# <link href="bootstrap/css/bootstrap.min.css" rel="stylesheet"/>
# <link href="estiloOngs.css" rel="stylesheet" type="text/css"/>
# <link href="http://www.ongsbrasil.com.br/default.asp?Pag=1&amp;Destino=Instituicoes" rel="canonical">
# <script>
# ...
